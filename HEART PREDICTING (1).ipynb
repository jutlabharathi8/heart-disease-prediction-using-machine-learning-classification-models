# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("heart_failure_clinical_records_dataset.csv");

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
df.shape
# Out:
# (299, 13)

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df.age
# Out:
# 0      75.0
# 1      55.0
# 2      65.0
# 3      50.0
# 4      65.0
#        ...
# 294    62.0
# 295    55.0
# 296    45.0
# 297    45.0
# 298    50.0
# Name: age, Length: 299, dtype: float64

# %%
df[['age','anaemia']]
# Out:
#       age  anaemia
# 0    75.0        0
# 1    55.0        0
# 2    65.0        0
# 3    50.0        1
# 4    65.0        1
# ..    ...      ...
# 294  62.0        0
# 295  55.0        0
# 296  45.0        0
# 297  45.0        0
# 298  50.0        0
#
# [299 rows x 2 columns]

# %%
df.sort_values(by='diabetes',ascending=False).head()
# Out:
#         age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 188  60.667        1                       151         1                 40
# 98   60.000        1                       156         1                 25
# 96   63.000        1                       514         1                 25
# 94   58.000        0                       144         1                 38
# 187  60.000        0                      1896         1                 25
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 188                    1   201000.0               1.0           136    0
# 98                     1   318000.0               1.2           137    0
# 96                     1   254000.0               1.3           134    1
# 94                     1   327000.0               0.7           142    0
# 187                    0   365000.0               2.1           144    0
#
#      smoking  time  DEATH_EVENT
# 188        0   172            0
# ...

# %%
df.sort_values(by='diabetes',ascending=False)
# Out:
#         age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 188  60.667        1                       151         1                 40
# 98   60.000        1                       156         1                 25
# 96   63.000        1                       514         1                 25
# 94   58.000        0                       144         1                 38
# 187  60.000        0                      1896         1                 25
# ..      ...      ...                       ...       ...                ...
# 135  75.000        0                       582         0                 40
# 137  68.000        1                       646         0                 25
# 139  50.000        0                      1548         0                 30
# 140  80.000        0                       805         0                 38
# 298  50.000        0                       196         0                 45
#
# ...

# %%
df.sort_values(by=['creatinine_phosphokinase','diabetes'])
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 31   85.0        0                        23         0                 45
# 151  62.0        0                        30         1                 60
# 5    90.0        1                        47         0                 40
# 75   60.0        1                        47         0                 20
# 86   55.0        0                        47         0                 35
# ..    ...      ...                       ...       ...                ...
# 134  81.0        0                      4540         0                 35
# 103  42.0        0                      5209         0                 30
# 72   85.0        0                      5882         0                 35
# 60   45.0        0                      7702         1                 25
# 1    55.0        0                      7861         0                 38
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %%
df.tail()
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 294                    1   155000.0               1.1           143    1
# 295                    0   270000.0               1.2           139    0
# 296                    0   742000.0               0.8           138    0
# 297                    0   140000.0               1.4           140    1
# 298                    0   395000.0               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 294        1   270            0
# ...

# %%
df.isnull()
# Out:
#        age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    False    False                     False     False              False
# 1    False    False                     False     False              False
# 2    False    False                     False     False              False
# 3    False    False                     False     False              False
# 4    False    False                     False     False              False
# ..     ...      ...                       ...       ...                ...
# 294  False    False                     False     False              False
# 295  False    False                     False     False              False
# 296  False    False                     False     False              False
# 297  False    False                     False     False              False
# 298  False    False                     False     False              False
#
# ...

# %%
df=df.dropna()

# %%
x=df.drop("DEATH_EVENT",axis=1)
y=df["DEATH_EVENT"]

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df["DEATH_EVENT"].value_counts()
# Out:
# 0    203
# 1     96
# Name: DEATH_EVENT, dtype: int64

# %%
df["age"].mean()
# Out:
# 60.83389297658862

# %%
df["sex"].value_counts()
# Out:
# 1    194
# 0    105
# Name: sex, dtype: int64

# %%
#comparing data death vs age
df.groupby("DEATH_EVENT")["age"].mean()
# Out:
# DEATH_EVENT
# 0    58.761906
# 1    65.215281
# Name: age, dtype: float64

# %%
#diabetes vs death
df.groupby("diabetes")["DEATH_EVENT"].mean()
# Out:
# diabetes
# 0    0.321839
# 1    0.320000
# Name: DEATH_EVENT, dtype: float64

# %%
#highBP vs death
df.groupby("high_blood_pressure")["DEATH_EVENT"].mean()
# Out:
# high_blood_pressure
# 0    0.293814
# 1    0.371429
# Name: DEATH_EVENT, dtype: float64

# %%
#visuvalization
df["DEATH_EVENT"].value_counts().plot(kind="bar")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#age distribution
df["age"].plot(kind="hist")
plt.show()

# %%
#diabetes vs death graph
df.groupby("diabetes")["DEATH_EVENT"].mean().plot(kind="bar")
plt.show()

# %% [markdown]
# ###### Higher age is associated with higher death risk
#
# Patients with high blood pressure show higher death rate
#
# Diabetes may influence heart condition
